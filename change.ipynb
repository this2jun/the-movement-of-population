# %%
import requests
import json

def translate(text):
    client_id = "7RS7MwqsnfnOtbjBeVLy" 
    client_secret = "bDbsyfcDMD" 
    url = "https://openapi.naver.com/v1/papago/n2mt"
    headers = {"X-Naver-Client-Id": client_id, "X-Naver-Client-Secret": client_secret}
    params = {"source": "ko", "target": "en", "text": text}
    response = requests.post(url, headers=headers, data=params)
    res = json.loads(response.text)
    return res['message']['result']['translatedText']

districts = ["영등포동", "서교동", "회현동", "광희동", "신촌동", "역삼1동", "명동", "제기동", "을지로동", "여의동", "소공동", "화양동", "반포4동", "삼성1동", "압구정동", "잠실6동", "논현2동", "한강로동", "상암동", "대치2동", "서초3동", "논현1동", "양재1동", "청담동", "대치4동", "역삼2동", "사직동", "이화동", "사근동", "잠실3동", "서초2동", "서초4동", "충현동", "가산동", "공덕동", "문정2동", "용신동", "대조동", "혜화동", "방이2동", "대학동", "안암동", "한남동", "삼성2동", "황학동", "문래동", "조원동", "목1동", "연희동", "연남동", "북아현동", "서강동", "합정동", "잠실본동", "청룡동", "양재2동", "상계2동", "흑석동", "삼선동", "대치1동", "길동", "도곡1동", "동선동", "대흥동", "왕십리도선동", "회기동", "석관동", "면목본동", "진관동", "남영동", "공릉2동", "망우본동", "필동", "석촌동", "목5동", "청파동", "공항동", "서초1동", "신도림동", "송파1동", "반포1동", "신정4동", "군자동", "인헌동", "청운효자동", "풍납2동", "중계본동", "종암동", "송천동", "잠원동", "낙성대동", "서원동", "가락본동", "하계1동", "신내1동", "아현동", "개포2동", "장충동", "반포3동", "방배4동", "방이1동", "인수동", "반포2동", "대방동", "도화동", "도곡2동", "광장동", "방배1동", "방배본동", "용강동", "은천동", "송중동", "강일동", "마장동", "월계1동", "신정3동", "상계5동", "중계1동", "신정1동", "신수동", "문정1동", "염창동", "잠실2동", "신정6동", "우장산동", "목2동", "신림동", "상계8동", "염리동", "목4동", "가락1동", "오금동", "신정7동", "일원본동", "청량리동", "가회동", "녹번동", "신정2동", "수서동", "용산2가동", "성북동", "용답동", "세곡동", "내곡동", "화곡본동", "서빙고동", "역촌동", "도림동", "영등포본동", "삼전동", "미아동", "신내2동", "신원동", "신월1동", "서림동", "마천2동", "오륜동", "중림동", "남현동", "우이동", "옥수동", "수색동", "잠실4동", "장지동", "능동", "천연동", "방배2동", "개포4동", "보광동", "상계1동", "후암동", "중앙동", "가락2동", "신사동", "신사동", "신사동", "신사동", "상계10동", "구산동", "보문동", "삼청동", "월계3동", "난곡동", "신월7동", "삼양동", "중계4동", "행운동", "송파2동", "삼성동", "미성동", "삼각산동", "증산동", "목3동", "용문동", "신월2동", "거여2동", "방배3동", "교남동", "금호1가동", "상계9동", "풍납1동", "일원2동", "신월6동", "가리봉동", "부암동", "월계2동", "일원1동", "평창동", "성현동", "보라매동", "금호4가동", "거여1동", "무악동", "수궁동", "송정동", "개포1동", "하계2동", "신월5동", "잠실7동", "효창동", "응봉동", "마천1동", "신월4동", "신월3동", "청림동", "난향동", "반포본동"]

translated_districts = [translate(district) for district in districts]
print(translated_districts)
